# %%
# !pip install mysqlclient 
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine 
import mysql

# %%
csv = 'YardvilleTags2018.csv'
Yardville_tagsDF = pd.read_csv(csv)
Yardville_tagsDF.head()
# Out:
#            X          Y   FID    Citation_N                      Date  \
# 0 -93.288902  45.043098  3001  271118359139  2018-02-26T00:00:00.000Z
# 1 -93.288895  45.043255  3002  271118359140  2018-02-26T00:00:00.000Z
# 2 -93.271568  44.914726  3003  271118343680  2018-02-26T00:00:00.000Z
# 3 -93.290146  45.043591  3004  271118359150  2018-02-26T00:00:00.000Z
# 4 -93.288879  45.043571  3005  271118359141  2018-02-26T00:00:00.000Z
#
#               Address   Latitude  Longitude    Ordinance  \
# 0   4834 CAMDEN AVE N  45.043098 -93.288902  478.1000(b)
# 1   4838 CAMDEN AVE N  45.043255 -93.288895  478.1000(b)
# 2  4844 CLINTON AVE S  44.914726 -93.271568  478.1000(b)
# 3  4850 ALDRICH AVE N  45.043591 -93.290146  478.1000(b)
# 4   4854 CAMDEN AVE N  45.043571 -93.288879  478.1000(b)
#
#                                           Ordinanc_1      Neighborho  \
# 0  Snow emergency parking restrictions - even num...  Lind - Bohanon
# ...

# %%
tempdf = Yardville_tagsDF.copy()

# %%
tempdf = tempdf.loc[:,["FID",
"Citation_N",
"Snow_Em_Na",
"Date",
"Address",
"Latitude",
"Longitude",
"Day_ID",
"Ordinance",
'Ordinanc_1',
'Ward',
"Neighborho",
"Community",
"Tow_Distri"]]

# %%
tempdf.head()
# Out:
#     FID    Citation_N Snow_Em_Na                      Date  \
# 0  3001  271118359139     Xerxes  2018-02-26T00:00:00.000Z
# 1  3002  271118359140     Xerxes  2018-02-26T00:00:00.000Z
# 2  3003  271118343680     Xerxes  2018-02-26T00:00:00.000Z
# 3  3004  271118359150     Xerxes  2018-02-26T00:00:00.000Z
# 4  3005  271118359141     Xerxes  2018-02-26T00:00:00.000Z
#
#               Address   Latitude  Longitude  Day_ID    Ordinance  \
# 0   4834 CAMDEN AVE N  45.043098 -93.288902       2  478.1000(b)
# 1   4838 CAMDEN AVE N  45.043255 -93.288895       2  478.1000(b)
# 2  4844 CLINTON AVE S  44.914726 -93.271568       2  478.1000(b)
# 3  4850 ALDRICH AVE N  45.043591 -93.290146       2  478.1000(b)
# 4   4854 CAMDEN AVE N  45.043571 -93.288879       2  478.1000(b)
#
#                                           Ordinanc_1  Ward      Neighborho  \
# 0  Snow emergency parking restrictions - even num...     4  Lind - Bohanon
# ...

# %%
tempdf = tempdf.rename(
    columns={"Snow_Em_Na": "snow_emergency_name",
            "Citation_N": "citation",
            "Date": "service_date",
            "Address": "address",
            "Latitude": "latitude",
            "Longitude": "longitude",
            "Day_ID": "day_id",
            "Ordinance": "ordinance_id",
            "Ordinanc_1": "ordinance_desc",
            "Ward": "ward",
            "Neighborho": "neighborhood",
            "Community": "community",
            "Tow_Distri": "tow_district"})

# %%
tempdf.head()
# Out:
#     FID      citation snow_emergency_name              service_date  \
# 0  3001  271118359139              Xerxes  2018-02-26T00:00:00.000Z
# 1  3002  271118359140              Xerxes  2018-02-26T00:00:00.000Z
# 2  3003  271118343680              Xerxes  2018-02-26T00:00:00.000Z
# 3  3004  271118359150              Xerxes  2018-02-26T00:00:00.000Z
# 4  3005  271118359141              Xerxes  2018-02-26T00:00:00.000Z
#
#               address   latitude  longitude  day_id ordinance_id  \
# 0   4834 CAMDEN AVE N  45.043098 -93.288902       2  478.1000(b)
# 1   4838 CAMDEN AVE N  45.043255 -93.288895       2  478.1000(b)
# 2  4844 CLINTON AVE S  44.914726 -93.271568       2  478.1000(b)
# 3  4850 ALDRICH AVE N  45.043591 -93.290146       2  478.1000(b)
# 4   4854 CAMDEN AVE N  45.043571 -93.288879       2  478.1000(b)
#
#                                       ordinance_desc  ward    neighborhood  \
# 0  Snow emergency parking restrictions - even num...     4  Lind - Bohanon
# ...

# %%
len(tempdf.FID.unique())
# Out:
# 3857

# %%
tempdf['service_date']=pd.to_datetime(tempdf['service_date'].astype(str).str[:10])

# %%
tempdf['latitude']=round(tempdf['latitude'],3)

# %%
tempdf['longitude']=round(tempdf['longitude'],3)

# %%
finaldf = tempdf
finaldf.head()
# Out:
#     FID      citation snow_emergency_name service_date             address  \
# 0  3001  271118359139              Xerxes   2018-02-26   4834 CAMDEN AVE N
# 1  3002  271118359140              Xerxes   2018-02-26   4838 CAMDEN AVE N
# 2  3003  271118343680              Xerxes   2018-02-26  4844 CLINTON AVE S
# 3  3004  271118359150              Xerxes   2018-02-26  4850 ALDRICH AVE N
# 4  3005  271118359141              Xerxes   2018-02-26   4854 CAMDEN AVE N
#
#    latitude  longitude  day_id ordinance_id  \
# 0    45.043    -93.289       2  478.1000(b)
# 1    45.043    -93.289       2  478.1000(b)
# 2    44.915    -93.272       2  478.1000(b)
# 3    45.044    -93.290       2  478.1000(b)
# 4    45.044    -93.289       2  478.1000(b)
#
#                                       ordinance_desc  ward    neighborhood  \
# 0  Snow emergency parking restrictions - even num...     4  Lind - Bohanon
# 1  Snow emergency parking restrictions - even num...     4  Lind - Bohanon
# ...

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://root:sadie9564@localhost/snow_emergency_db")

# %%
finaldf = tempdf.to_sql(name="yardville_tags_base", con=engine, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1209                     self.dialect.do_executemany(
# -> 1210                         cursor, statement, parameters, context
#    1211                     )
#
# ~\Anaconda\envs\PythonData\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# ~\Anaconda\envs\PythonData\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...
